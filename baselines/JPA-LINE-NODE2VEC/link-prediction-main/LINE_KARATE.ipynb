# %%
import pandas as pd
import numpy as np
import networkx as nx
import itertools
import pickle
import os
import random
from sklearn.model_selection import train_test_split

from sklearn.metrics import average_precision_score
from sklearn import metrics

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

from ge import LINE

# %%
def get_edges_dict(traindata):
    if os.path.isfile("edgesdic.pkl"):
        f = open("edgesdic.pkl","rb")
        edges = pickle.load(f)
        f.close()
        return edges
    else:
        edges = dict()
        for edge in range(len(traindata)): 
            edges[(traindata.loc[[edge]]['id_1'].values[0],traindata.loc[[edge]]['id_2'].values[0])] = 1 
            edges[(traindata.loc[[edge]]['id_2'].values[0],traindata.loc[[edge]]['id_1'].values[0])] = 1  
        f = open("edgesdic.pkl","wb")
        pickle.dump(edges,f)
        f.close()
        return edges

def get_negative_edges(traindata,g):
    edges = get_edges_dict(traindata)
    # for missing edges.
    negative_edges = set([])
    maxNodenum = max(max(traindata['id_1']),max(traindata['id_2']))
    #產生與原圖同edge數目的negative edges
    while (len(negative_edges)<len(traindata)*2):
        node1=random.randint(0, maxNodenum) 
        node2=random.randint(0, maxNodenum) 
        tmp = edges.get((node1,node2),0) #edge不在graph裡標為0
        if tmp == 0 and node1!=node2 and g.has_node(node1) and g.has_node(node2): # if edge不在graph裡才要做處理
            negative_edges.add((node1,node2))
        else:
            continue
    return negative_edges

# %%
def combine_embedding(data,embeddings):
    i=0
    X = []
    for node1,node2 in data:
        X.append(np.concatenate((data[i],embeddings[int(node1)],embeddings[int(node2)])))
   # print(embeddings[str(int(data[0]))])
        i+=1
    return X

# %%
ori_df = pd.read_csv('data/karate_edges.txt', header=None, sep=' ')
ori_df.columns = ['id_1', 'id_2']

ori_G = nx.from_pandas_edgelist(ori_df, 'id_1', 'id_2')

# %%
model = LINE(ori_G, embedding_size=8, order='all')
model.train(batch_size=12, epochs=300, verbose=2)
LINE_embeddings = model.get_embeddings()
# Out:
# WARNING:tensorflow:From C:\Users\zhangshanfan\.conda\envs\tf1.x\lib\site-packages\tensorflow_core\python\keras\initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\zhangshanfan\.conda\envs\tf1.x\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\Users\zhangshanfan\.conda\envs\tf1.x\lib\site-packages\deepctr-0.9.2-py3.6.egg\deepctr\layers\utils.py:225: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Epoch 1/300
# 39/39 - 0s - loss: 1.3862 - first_order_loss: 0.6933 - second_order_loss: 0.6929
# Epoch 2/300
# 39/39 - 0s - loss: 1.3853 - first_order_loss: 0.6931 - second_order_loss: 0.6922
# Epoch 3/300
# 39/39 - 0s - loss: 1.3835 - first_order_loss: 0.6931 - second_order_loss: 0.6904
# Epoch 4/300
# 39/39 - 0s - loss: 1.3790 - first_order_loss: 0.6932 - second_order_loss: 0.6858
# Epoch 5/300
# 39/39 - 0s - loss: 1.3714 - first_order_loss: 0.6929 - second_order_loss: 0.6784
# Epoch 6/300
# 39/39 - 0s - loss: 1.3568 - first_order_loss: 0.6929 - second_order_loss: 0.6639
# Epoch 7/300
# 39/39 - 0s - loss: 1.3399 - first_order_loss: 0.6928 - second_order_loss: 0.6471
# Epoch 8/300
# 39/39 - 0s - loss: 1.3157 - first_order_loss: 0.6930 - second_order_loss: 0.6227
# Epoch 9/300
# 39/39 - 0s - loss: 1.2843 - first_order_loss: 0.6927 - second_order_loss: 0.5917
# Epoch 10/300
# 39/39 - 0s - loss: 1.2437 - first_order_loss: 0.6926 - second_order_loss: 0.5511
# Epoch 11/300
# 39/39 - 0s - loss: 1.2172 - first_order_loss: 0.6918 - second_order_loss: 0.5254
# Epoch 12/300
# 39/39 - 0s - loss: 1.1804 - first_order_loss: 0.6926 - second_order_loss: 0.4878
# Epoch 13/300
# 39/39 - 0s - loss: 1.1579 - first_order_loss: 0.6918 - second_order_loss: 0.4661
# Epoch 14/300
# 39/39 - 0s - loss: 1.1324 - first_order_loss: 0.6918 - second_order_loss: 0.4406
# Epoch 15/300
# 39/39 - 0s - loss: 1.1183 - first_order_loss: 0.6907 - second_order_loss: 0.4277
# Epoch 16/300
# 39/39 - 0s - loss: 1.0819 - first_order_loss: 0.6915 - second_order_loss: 0.3903
# Epoch 17/300
# 39/39 - 0s - loss: 1.0910 - first_order_loss: 0.6911 - second_order_loss: 0.3999
# Epoch 18/300
# WARNING:root:
# DeepCTR version 0.9.3 detected. Your version is 0.9.2.
# Use `pip install -U deepctr` to upgrade.Changelog: https://github.com/shenweichen/DeepCTR/releases/tag/v0.9.3
# 39/39 - 0s - loss: 1.0445 - first_order_loss: 0.6900 - second_order_loss: 0.3547
# Epoch 19/300
# 39/39 - 0s - loss: 1.0706 - first_order_loss: 0.6900 - second_order_loss: 0.3807
# Epoch 20/300
# 39/39 - 0s - loss: 0.9966 - first_order_loss: 0.6879 - second_order_loss: 0.3085
# Epoch 21/300
# 39/39 - 0s - loss: 1.0460 - first_order_loss: 0.6890 - second_order_loss: 0.3572
# Epoch 22/300
# 39/39 - 0s - loss: 1.0279 - first_order_loss: 0.6895 - second_order_loss: 0.3384
# Epoch 23/300
# 39/39 - 0s - loss: 1.0175 - first_order_loss: 0.6840 - second_order_loss: 0.3335
# Epoch 24/300
# 39/39 - 0s - loss: 0.9755 - first_order_loss: 0.6876 - second_order_loss: 0.2878
# Epoch 25/300
# 39/39 - 0s - loss: 1.0082 - first_order_loss: 0.6836 - second_order_loss: 0.3245
# Epoch 26/300
# 39/39 - 0s - loss: 0.9956 - first_order_loss: 0.6850 - second_order_loss: 0.3106
# Epoch 27/300
# 39/39 - 0s - loss: 0.9836 - first_order_loss: 0.6796 - second_order_loss: 0.3040
# Epoch 28/300
# 39/39 - 0s - loss: 0.9771 - first_order_loss: 0.6845 - second_order_loss: 0.2925
# Epoch 29/300
# 39/39 - 0s - loss: 0.9926 - first_order_loss: 0.6836 - second_order_loss: 0.3092
# Epoch 30/300
# 39/39 - 0s - loss: 0.9709 - first_order_loss: 0.6843 - second_order_loss: 0.2865
# Epoch 31/300
# 39/39 - 0s - loss: 0.9941 - first_order_loss: 0.6781 - second_order_loss: 0.3160
# Epoch 32/300
# 39/39 - 0s - loss: 0.9698 - first_order_loss: 0.6827 - second_order_loss: 0.2871
# Epoch 33/300
# 39/39 - 0s - loss: 0.9652 - first_order_loss: 0.6750 - second_order_loss: 0.2902
# Epoch 34/300
# 39/39 - 0s - loss: 0.9528 - first_order_loss: 0.6762 - second_order_loss: 0.2766
# Epoch 35/300
# 39/39 - 0s - loss: 0.9645 - first_order_loss: 0.6711 - second_order_loss: 0.2934
# Epoch 36/300
# 39/39 - 0s - loss: 0.9769 - first_order_loss: 0.6850 - second_order_loss: 0.2917
# Epoch 37/300
# 39/39 - 0s - loss: 0.9520 - first_order_loss: 0.6756 - second_order_loss: 0.2764
# Epoch 38/300
# 39/39 - 0s - loss: 0.9315 - first_order_loss: 0.6701 - second_order_loss: 0.2613
# Epoch 39/300
# 39/39 - 0s - loss: 0.9801 - first_order_loss: 0.6777 - second_order_loss: 0.3022
# Epoch 40/300
# 39/39 - 0s - loss: 0.9400 - first_order_loss: 0.6705 - second_order_loss: 0.2695
# Epoch 41/300
# 39/39 - 0s - loss: 0.9643 - first_order_loss: 0.6721 - second_order_loss: 0.2922
# Epoch 42/300
# 39/39 - 0s - loss: 0.9386 - first_order_loss: 0.6705 - second_order_loss: 0.2682
# Epoch 43/300
# 39/39 - 0s - loss: 0.9594 - first_order_loss: 0.6710 - second_order_loss: 0.2884
# Epoch 44/300
# 39/39 - 0s - loss: 0.9631 - first_order_loss: 0.6789 - second_order_loss: 0.2841
# Epoch 45/300
# 39/39 - 0s - loss: 0.9682 - first_order_loss: 0.6836 - second_order_loss: 0.2845
# Epoch 46/300
# 39/39 - 0s - loss: 0.9298 - first_order_loss: 0.6727 - second_order_loss: 0.2569
# Epoch 47/300
# 39/39 - 0s - loss: 0.9755 - first_order_loss: 0.6794 - second_order_loss: 0.2962
# Epoch 48/300
# 39/39 - 0s - loss: 0.9267 - first_order_loss: 0.6742 - second_order_loss: 0.2524
# Epoch 49/300
# 39/39 - 0s - loss: 0.9586 - first_order_loss: 0.6655 - second_order_loss: 0.2930
# Epoch 50/300
# 39/39 - 0s - loss: 0.9190 - first_order_loss: 0.6703 - second_order_loss: 0.2487
# Epoch 51/300
# 39/39 - 0s - loss: 0.9745 - first_order_loss: 0.6708 - second_order_loss: 0.3041
# Epoch 52/300
# 39/39 - 0s - loss: 0.9433 - first_order_loss: 0.6791 - second_order_loss: 0.2643
# Epoch 53/300
# 39/39 - 0s - loss: 0.9416 - first_order_loss: 0.6686 - second_order_loss: 0.2730
# Epoch 54/300
# 39/39 - 0s - loss: 0.9049 - first_order_loss: 0.6658 - second_order_loss: 0.2388
# Epoch 55/300
# 39/39 - 0s - loss: 0.9364 - first_order_loss: 0.6578 - second_order_loss: 0.2783
# Epoch 56/300
# 39/39 - 0s - loss: 0.9473 - first_order_loss: 0.6737 - second_order_loss: 0.2739
# Epoch 57/300
# 39/39 - 0s - loss: 0.9600 - first_order_loss: 0.6750 - second_order_loss: 0.2851
# Epoch 58/300
# 39/39 - 0s - loss: 0.9301 - first_order_loss: 0.6671 - second_order_loss: 0.2628
# Epoch 59/300
# 39/39 - 0s - loss: 0.9362 - first_order_loss: 0.6582 - second_order_loss: 0.2780
# Epoch 60/300
# 39/39 - 0s - loss: 0.9241 - first_order_loss: 0.6708 - second_order_loss: 0.2533
# Epoch 61/300
# 39/39 - 0s - loss: 0.9240 - first_order_loss: 0.6606 - second_order_loss: 0.2633
# Epoch 62/300
# 39/39 - 0s - loss: 0.9335 - first_order_loss: 0.6680 - second_order_loss: 0.2657
# Epoch 63/300
# 39/39 - 0s - loss: 0.9158 - first_order_loss: 0.6606 - second_order_loss: 0.2552
# Epoch 64/300
# 39/39 - 0s - loss: 0.9462 - first_order_loss: 0.6642 - second_order_loss: 0.2822
# Epoch 65/300
# 39/39 - 0s - loss: 0.9422 - first_order_loss: 0.6583 - second_order_loss: 0.2839
# Epoch 66/300
# 39/39 - 0s - loss: 0.8989 - first_order_loss: 0.6713 - second_order_loss: 0.2277
# Epoch 67/300
# 39/39 - 0s - loss: 0.9192 - first_order_loss: 0.6521 - second_order_loss: 0.2670
# Epoch 68/300
# 39/39 - 0s - loss: 0.9387 - first_order_loss: 0.6715 - second_order_loss: 0.2671
# Epoch 69/300
# 39/39 - 0s - loss: 0.9102 - first_order_loss: 0.6519 - second_order_loss: 0.2579
# Epoch 70/300
# 39/39 - 0s - loss: 0.9167 - first_order_loss: 0.6629 - second_order_loss: 0.2538
# Epoch 71/300
# 39/39 - 0s - loss: 0.9159 - first_order_loss: 0.6568 - second_order_loss: 0.2590
# Epoch 72/300
# 39/39 - 0s - loss: 0.9131 - first_order_loss: 0.6713 - second_order_loss: 0.2418
# Epoch 73/300
# 39/39 - 0s - loss: 0.9471 - first_order_loss: 0.6653 - second_order_loss: 0.2820
# Epoch 74/300
# 39/39 - 0s - loss: 0.9181 - first_order_loss: 0.6708 - second_order_loss: 0.2474
# Epoch 75/300
# 39/39 - 0s - loss: 0.9257 - first_order_loss: 0.6607 - second_order_loss: 0.2651
# Epoch 76/300
# 39/39 - 0s - loss: 0.9166 - first_order_loss: 0.6717 - second_order_loss: 0.2449
# Epoch 77/300
# 39/39 - 0s - loss: 0.9319 - first_order_loss: 0.6644 - second_order_loss: 0.2677
# Epoch 78/300
# 39/39 - 0s - loss: 0.9405 - first_order_loss: 0.6660 - second_order_loss: 0.2751
# Epoch 79/300
# 39/39 - 0s - loss: 0.9510 - first_order_loss: 0.6686 - second_order_loss: 0.2825
# Epoch 80/300
# 39/39 - 0s - loss: 0.9349 - first_order_loss: 0.6765 - second_order_loss: 0.2585
# Epoch 81/300
# 39/39 - 0s - loss: 0.9057 - first_order_loss: 0.6440 - second_order_loss: 0.2617
# Epoch 82/300
# 39/39 - 0s - loss: 0.9145 - first_order_loss: 0.6724 - second_order_loss: 0.2419
# Epoch 83/300
# 39/39 - 0s - loss: 0.8998 - first_order_loss: 0.6458 - second_order_loss: 0.2538
# Epoch 84/300
# 39/39 - 0s - loss: 0.8903 - first_order_loss: 0.6519 - second_order_loss: 0.2381
# Epoch 85/300
# 39/39 - 0s - loss: 0.9152 - first_order_loss: 0.6579 - second_order_loss: 0.2573
# Epoch 86/300
# 39/39 - 0s - loss: 0.9025 - first_order_loss: 0.6611 - second_order_loss: 0.2413
# Epoch 87/300
# 39/39 - 0s - loss: 0.9270 - first_order_loss: 0.6634 - second_order_loss: 0.2638
# Epoch 88/300
# 39/39 - 0s - loss: 0.8982 - first_order_loss: 0.6560 - second_order_loss: 0.2422
# Epoch 89/300
# 39/39 - 0s - loss: 0.8978 - first_order_loss: 0.6453 - second_order_loss: 0.2525
# Epoch 90/300
# 39/39 - 0s - loss: 0.9110 - first_order_loss: 0.6602 - second_order_loss: 0.2510
# Epoch 91/300
# 39/39 - 0s - loss: 0.8874 - first_order_loss: 0.6553 - second_order_loss: 0.2321
# Epoch 92/300
# 39/39 - 0s - loss: 0.9359 - first_order_loss: 0.6631 - second_order_loss: 0.2730
# Epoch 93/300
# 39/39 - 0s - loss: 0.9241 - first_order_loss: 0.6637 - second_order_loss: 0.2601
# Epoch 94/300
# 39/39 - 0s - loss: 0.8860 - first_order_loss: 0.6536 - second_order_loss: 0.2326
# Epoch 95/300
# 39/39 - 0s - loss: 0.9237 - first_order_loss: 0.6485 - second_order_loss: 0.2751
# Epoch 96/300
# 39/39 - 0s - loss: 0.8991 - first_order_loss: 0.6635 - second_order_loss: 0.2357
# Epoch 97/300
# 39/39 - 0s - loss: 0.9136 - first_order_loss: 0.6541 - second_order_loss: 0.2596
# Epoch 98/300
# 39/39 - 0s - loss: 0.8974 - first_order_loss: 0.6617 - second_order_loss: 0.2355
# Epoch 99/300
# 39/39 - 0s - loss: 0.9034 - first_order_loss: 0.6483 - second_order_loss: 0.2553
# Epoch 100/300
# 39/39 - 0s - loss: 0.9172 - first_order_loss: 0.6735 - second_order_loss: 0.2436
# Epoch 101/300
# 39/39 - 0s - loss: 0.9027 - first_order_loss: 0.6585 - second_order_loss: 0.2441
# Epoch 102/300
# 39/39 - 0s - loss: 0.9175 - first_order_loss: 0.6779 - second_order_loss: 0.2398
# Epoch 103/300
# 39/39 - 0s - loss: 0.9253 - first_order_loss: 0.6580 - second_order_loss: 0.2676
# Epoch 104/300
# 39/39 - 0s - loss: 0.9160 - first_order_loss: 0.6681 - second_order_loss: 0.2479
# Epoch 105/300
# 39/39 - 0s - loss: 0.8674 - first_order_loss: 0.6433 - second_order_loss: 0.2239
# Epoch 106/300
# 39/39 - 0s - loss: 0.9084 - first_order_loss: 0.6652 - second_order_loss: 0.2433
# Epoch 107/300
# 39/39 - 0s - loss: 0.9185 - first_order_loss: 0.6542 - second_order_loss: 0.2643
# Epoch 108/300
# 39/39 - 0s - loss: 0.8804 - first_order_loss: 0.6589 - second_order_loss: 0.2213
# Epoch 109/300
# 39/39 - 0s - loss: 0.9118 - first_order_loss: 0.6639 - second_order_loss: 0.2477
# Epoch 110/300
# 39/39 - 0s - loss: 0.8852 - first_order_loss: 0.6609 - second_order_loss: 0.2244
# Epoch 111/300
# 39/39 - 0s - loss: 0.8990 - first_order_loss: 0.6605 - second_order_loss: 0.2383
# Epoch 112/300
# 39/39 - 0s - loss: 0.9120 - first_order_loss: 0.6747 - second_order_loss: 0.2372
# Epoch 113/300
# 39/39 - 0s - loss: 0.9116 - first_order_loss: 0.6600 - second_order_loss: 0.2517
# Epoch 114/300
# 39/39 - 0s - loss: 0.9016 - first_order_loss: 0.6644 - second_order_loss: 0.2372
# Epoch 115/300
# 39/39 - 0s - loss: 0.8958 - first_order_loss: 0.6525 - second_order_loss: 0.2433
# Epoch 116/300
# 39/39 - 0s - loss: 0.9022 - first_order_loss: 0.6613 - second_order_loss: 0.2411
# Epoch 117/300
# 39/39 - 0s - loss: 0.9102 - first_order_loss: 0.6600 - second_order_loss: 0.2503
# Epoch 118/300
# 39/39 - 0s - loss: 0.8890 - first_order_loss: 0.6517 - second_order_loss: 0.2373
# Epoch 119/300
# 39/39 - 0s - loss: 0.8685 - first_order_loss: 0.6425 - second_order_loss: 0.2259
# Epoch 120/300
# 39/39 - 0s - loss: 0.8832 - first_order_loss: 0.6529 - second_order_loss: 0.2302
# Epoch 121/300
# 39/39 - 0s - loss: 0.8675 - first_order_loss: 0.6404 - second_order_loss: 0.2269
# Epoch 122/300
# 39/39 - 0s - loss: 0.8858 - first_order_loss: 0.6556 - second_order_loss: 0.2302
# Epoch 123/300
# 39/39 - 0s - loss: 0.9224 - first_order_loss: 0.6592 - second_order_loss: 0.2631
# Epoch 124/300
# 39/39 - 0s - loss: 0.8573 - first_order_loss: 0.6564 - second_order_loss: 0.2009
# Epoch 125/300
# 39/39 - 0s - loss: 0.9020 - first_order_loss: 0.6504 - second_order_loss: 0.2515
# Epoch 126/300
# 39/39 - 0s - loss: 0.8933 - first_order_loss: 0.6614 - second_order_loss: 0.2321
# Epoch 127/300
# 39/39 - 0s - loss: 0.9005 - first_order_loss: 0.6507 - second_order_loss: 0.2497
# Epoch 128/300
# 39/39 - 0s - loss: 0.8882 - first_order_loss: 0.6651 - second_order_loss: 0.2230
# Epoch 129/300
# 39/39 - 0s - loss: 0.8946 - first_order_loss: 0.6557 - second_order_loss: 0.2388
# Epoch 130/300
# 39/39 - 0s - loss: 0.8766 - first_order_loss: 0.6572 - second_order_loss: 0.2194
# Epoch 131/300
# 39/39 - 0s - loss: 0.9250 - first_order_loss: 0.6587 - second_order_loss: 0.2663
# Epoch 132/300
# 39/39 - 0s - loss: 0.8654 - first_order_loss: 0.6506 - second_order_loss: 0.2148
# Epoch 133/300
# 39/39 - 0s - loss: 0.9125 - first_order_loss: 0.6586 - second_order_loss: 0.2540
# Epoch 134/300
# 39/39 - 0s - loss: 0.8746 - first_order_loss: 0.6612 - second_order_loss: 0.2134
# Epoch 135/300
# 39/39 - 0s - loss: 0.8817 - first_order_loss: 0.6598 - second_order_loss: 0.2220
# Epoch 136/300
# 39/39 - 0s - loss: 0.9153 - first_order_loss: 0.6650 - second_order_loss: 0.2505
# Epoch 137/300
# 39/39 - 0s - loss: 0.8803 - first_order_loss: 0.6482 - second_order_loss: 0.2318
# Epoch 138/300
# 39/39 - 0s - loss: 0.8672 - first_order_loss: 0.6559 - second_order_loss: 0.2113
# Epoch 139/300
# 39/39 - 0s - loss: 0.8981 - first_order_loss: 0.6594 - second_order_loss: 0.2389
# Epoch 140/300
# 39/39 - 0s - loss: 0.8863 - first_order_loss: 0.6673 - second_order_loss: 0.2191
# Epoch 141/300
# 39/39 - 0s - loss: 0.8751 - first_order_loss: 0.6529 - second_order_loss: 0.2221
# Epoch 142/300
# 39/39 - 0s - loss: 0.8722 - first_order_loss: 0.6644 - second_order_loss: 0.2076
# Epoch 143/300
# 39/39 - 0s - loss: 0.8796 - first_order_loss: 0.6522 - second_order_loss: 0.2273
# Epoch 144/300
# 39/39 - 0s - loss: 0.8550 - first_order_loss: 0.6504 - second_order_loss: 0.2045
# Epoch 145/300
# 39/39 - 0s - loss: 0.8932 - first_order_loss: 0.6461 - second_order_loss: 0.2471
# Epoch 146/300
# 39/39 - 0s - loss: 0.8485 - first_order_loss: 0.6528 - second_order_loss: 0.1956
# Epoch 147/300
# 39/39 - 0s - loss: 0.8785 - first_order_loss: 0.6500 - second_order_loss: 0.2285
# Epoch 148/300
# 39/39 - 0s - loss: 0.8636 - first_order_loss: 0.6494 - second_order_loss: 0.2144
# Epoch 149/300
# 39/39 - 0s - loss: 0.8972 - first_order_loss: 0.6541 - second_order_loss: 0.2432
# Epoch 150/300
# 39/39 - 0s - loss: 0.8822 - first_order_loss: 0.6580 - second_order_loss: 0.2243
# Epoch 151/300
# 39/39 - 0s - loss: 0.9017 - first_order_loss: 0.6634 - second_order_loss: 0.2383
# Epoch 152/300
# 39/39 - 0s - loss: 0.8362 - first_order_loss: 0.6413 - second_order_loss: 0.1948
# Epoch 153/300
# 39/39 - 0s - loss: 0.8844 - first_order_loss: 0.6539 - second_order_loss: 0.2303
# Epoch 154/300
# 39/39 - 0s - loss: 0.8410 - first_order_loss: 0.6439 - second_order_loss: 0.1969
# Epoch 155/300
# 39/39 - 0s - loss: 0.8734 - first_order_loss: 0.6516 - second_order_loss: 0.2219
# Epoch 156/300
# 39/39 - 0s - loss: 0.8505 - first_order_loss: 0.6470 - second_order_loss: 0.2034
# Epoch 157/300
# 39/39 - 0s - loss: 0.8879 - first_order_loss: 0.6513 - second_order_loss: 0.2367
# Epoch 158/300
# 39/39 - 0s - loss: 0.8632 - first_order_loss: 0.6544 - second_order_loss: 0.2090
# Epoch 159/300
# 39/39 - 0s - loss: 0.8975 - first_order_loss: 0.6544 - second_order_loss: 0.2434
# Epoch 160/300
# 39/39 - 0s - loss: 0.8445 - first_order_loss: 0.6468 - second_order_loss: 0.1978
# Epoch 161/300
# 39/39 - 0s - loss: 0.8545 - first_order_loss: 0.6439 - second_order_loss: 0.2105
# Epoch 162/300
# 39/39 - 0s - loss: 0.8900 - first_order_loss: 0.6642 - second_order_loss: 0.2257
# Epoch 163/300
# 39/39 - 0s - loss: 0.8719 - first_order_loss: 0.6561 - second_order_loss: 0.2159
# Epoch 164/300
# 39/39 - 0s - loss: 0.8690 - first_order_loss: 0.6635 - second_order_loss: 0.2057
# Epoch 165/300
# 39/39 - 0s - loss: 0.8643 - first_order_loss: 0.6512 - second_order_loss: 0.2131
# Epoch 166/300
# 39/39 - 0s - loss: 0.8608 - first_order_loss: 0.6501 - second_order_loss: 0.2105
# Epoch 167/300
# 39/39 - 0s - loss: 0.8722 - first_order_loss: 0.6515 - second_order_loss: 0.2205
# Epoch 168/300
# 39/39 - 0s - loss: 0.8635 - first_order_loss: 0.6638 - second_order_loss: 0.1998
# Epoch 169/300
# 39/39 - 0s - loss: 0.8710 - first_order_loss: 0.6499 - second_order_loss: 0.2213
# Epoch 170/300
# 39/39 - 0s - loss: 0.8652 - first_order_loss: 0.6576 - second_order_loss: 0.2076
# Epoch 171/300
# 39/39 - 0s - loss: 0.8550 - first_order_loss: 0.6487 - second_order_loss: 0.2060
# Epoch 172/300
# 39/39 - 0s - loss: 0.8550 - first_order_loss: 0.6564 - second_order_loss: 0.1986
# Epoch 173/300
# 39/39 - 0s - loss: 0.8755 - first_order_loss: 0.6554 - second_order_loss: 0.2203
# Epoch 174/300
# 39/39 - 0s - loss: 0.8893 - first_order_loss: 0.6557 - second_order_loss: 0.2337
# Epoch 175/300
# 39/39 - 0s - loss: 0.8318 - first_order_loss: 0.6303 - second_order_loss: 0.2013
# Epoch 176/300
# 39/39 - 0s - loss: 0.8394 - first_order_loss: 0.6490 - second_order_loss: 0.1904
# Epoch 177/300
# 39/39 - 0s - loss: 0.8579 - first_order_loss: 0.6531 - second_order_loss: 0.2050
# Epoch 178/300
# 39/39 - 0s - loss: 0.8805 - first_order_loss: 0.6653 - second_order_loss: 0.2153
# Epoch 179/300
# 39/39 - 0s - loss: 0.8713 - first_order_loss: 0.6595 - second_order_loss: 0.2117
# Epoch 180/300
# 39/39 - 0s - loss: 0.8453 - first_order_loss: 0.6535 - second_order_loss: 0.1920
# Epoch 181/300
# 39/39 - 0s - loss: 0.8422 - first_order_loss: 0.6356 - second_order_loss: 0.2066
# Epoch 182/300
# 39/39 - 0s - loss: 0.8569 - first_order_loss: 0.6495 - second_order_loss: 0.2076
# Epoch 183/300
# 39/39 - 0s - loss: 0.8636 - first_order_loss: 0.6397 - second_order_loss: 0.2240
# Epoch 184/300
# 39/39 - 0s - loss: 0.8416 - first_order_loss: 0.6530 - second_order_loss: 0.1885
# Epoch 185/300
# 39/39 - 0s - loss: 0.8616 - first_order_loss: 0.6457 - second_order_loss: 0.2158
# Epoch 186/300
# 39/39 - 0s - loss: 0.8413 - first_order_loss: 0.6603 - second_order_loss: 0.1809
# Epoch 187/300
# 39/39 - 0s - loss: 0.8415 - first_order_loss: 0.6454 - second_order_loss: 0.1961
# Epoch 188/300
# 39/39 - 0s - loss: 0.9073 - first_order_loss: 0.6730 - second_order_loss: 0.2345
# Epoch 189/300
# 39/39 - 0s - loss: 0.8286 - first_order_loss: 0.6345 - second_order_loss: 0.1940
# Epoch 190/300
# 39/39 - 0s - loss: 0.8797 - first_order_loss: 0.6722 - second_order_loss: 0.2075
# Epoch 191/300
# 39/39 - 0s - loss: 0.8343 - first_order_loss: 0.6392 - second_order_loss: 0.1949
# Epoch 192/300
# 39/39 - 0s - loss: 0.8695 - first_order_loss: 0.6656 - second_order_loss: 0.2041
# Epoch 193/300
# 39/39 - 0s - loss: 0.8295 - first_order_loss: 0.6490 - second_order_loss: 0.1805
# Epoch 194/300
# 39/39 - 0s - loss: 0.8684 - first_order_loss: 0.6627 - second_order_loss: 0.2060
# Epoch 195/300
# 39/39 - 0s - loss: 0.8643 - first_order_loss: 0.6485 - second_order_loss: 0.2157
# Epoch 196/300
# 39/39 - 0s - loss: 0.8268 - first_order_loss: 0.6440 - second_order_loss: 0.1829
# Epoch 197/300
# 39/39 - 0s - loss: 0.8572 - first_order_loss: 0.6438 - second_order_loss: 0.2137
# Epoch 198/300
# 39/39 - 0s - loss: 0.8425 - first_order_loss: 0.6565 - second_order_loss: 0.1860
# Epoch 199/300
# 39/39 - 0s - loss: 0.8334 - first_order_loss: 0.6509 - second_order_loss: 0.1823
# Epoch 200/300
# 39/39 - 0s - loss: 0.8281 - first_order_loss: 0.6504 - second_order_loss: 0.1776
# Epoch 201/300
# 39/39 - 0s - loss: 0.8549 - first_order_loss: 0.6397 - second_order_loss: 0.2153
# Epoch 202/300
# 39/39 - 0s - loss: 0.8518 - first_order_loss: 0.6513 - second_order_loss: 0.2005
# Epoch 203/300
# 39/39 - 0s - loss: 0.8416 - first_order_loss: 0.6427 - second_order_loss: 0.1987
# Epoch 204/300
# 39/39 - 0s - loss: 0.8260 - first_order_loss: 0.6542 - second_order_loss: 0.1717
# Epoch 205/300
# 39/39 - 0s - loss: 0.8644 - first_order_loss: 0.6469 - second_order_loss: 0.2176
# Epoch 206/300
# 39/39 - 0s - loss: 0.8345 - first_order_loss: 0.6488 - second_order_loss: 0.1859
# Epoch 207/300
# 39/39 - 0s - loss: 0.8612 - first_order_loss: 0.6474 - second_order_loss: 0.2137
# Epoch 208/300
# 39/39 - 0s - loss: 0.8343 - first_order_loss: 0.6481 - second_order_loss: 0.1862
# Epoch 209/300
# 39/39 - 0s - loss: 0.8466 - first_order_loss: 0.6343 - second_order_loss: 0.2124
# Epoch 210/300
# 39/39 - 0s - loss: 0.8491 - first_order_loss: 0.6565 - second_order_loss: 0.1927
# Epoch 211/300
# 39/39 - 0s - loss: 0.8373 - first_order_loss: 0.6404 - second_order_loss: 0.1969
# Epoch 212/300
# 39/39 - 0s - loss: 0.8296 - first_order_loss: 0.6517 - second_order_loss: 0.1777
# Epoch 213/300
# 39/39 - 0s - loss: 0.8539 - first_order_loss: 0.6479 - second_order_loss: 0.2061
# Epoch 214/300
# 39/39 - 0s - loss: 0.8399 - first_order_loss: 0.6477 - second_order_loss: 0.1923
# Epoch 215/300
# 39/39 - 0s - loss: 0.8604 - first_order_loss: 0.6426 - second_order_loss: 0.2178
# Epoch 216/300
# 39/39 - 0s - loss: 0.8604 - first_order_loss: 0.6474 - second_order_loss: 0.2133
# Epoch 217/300
# 39/39 - 0s - loss: 0.8646 - first_order_loss: 0.6551 - second_order_loss: 0.2097
# Epoch 218/300
# 39/39 - 0s - loss: 0.8114 - first_order_loss: 0.6356 - second_order_loss: 0.1757
# Epoch 219/300
# 39/39 - 0s - loss: 0.8199 - first_order_loss: 0.6358 - second_order_loss: 0.1840
# Epoch 220/300
# 39/39 - 0s - loss: 0.8373 - first_order_loss: 0.6498 - second_order_loss: 0.1875
# Epoch 221/300
# 39/39 - 0s - loss: 0.8474 - first_order_loss: 0.6468 - second_order_loss: 0.2005
# Epoch 222/300
# 39/39 - 0s - loss: 0.7974 - first_order_loss: 0.6378 - second_order_loss: 0.1595
# Epoch 223/300
# 39/39 - 0s - loss: 0.8319 - first_order_loss: 0.6372 - second_order_loss: 0.1948
# Epoch 224/300
# 39/39 - 0s - loss: 0.8453 - first_order_loss: 0.6620 - second_order_loss: 0.1835
# Epoch 225/300
# 39/39 - 0s - loss: 0.8234 - first_order_loss: 0.6358 - second_order_loss: 0.1877
# Epoch 226/300
# 39/39 - 0s - loss: 0.8171 - first_order_loss: 0.6487 - second_order_loss: 0.1683
# Epoch 227/300
# 39/39 - 0s - loss: 0.8365 - first_order_loss: 0.6310 - second_order_loss: 0.2057
# Epoch 228/300
# 39/39 - 0s - loss: 0.8437 - first_order_loss: 0.6589 - second_order_loss: 0.1849
# Epoch 229/300
# 39/39 - 0s - loss: 0.8315 - first_order_loss: 0.6329 - second_order_loss: 0.1984
# Epoch 230/300
# 39/39 - 0s - loss: 0.8033 - first_order_loss: 0.6465 - second_order_loss: 0.1567
# Epoch 231/300
# 39/39 - 0s - loss: 0.8217 - first_order_loss: 0.6369 - second_order_loss: 0.1849
# Epoch 232/300
# 39/39 - 0s - loss: 0.8246 - first_order_loss: 0.6508 - second_order_loss: 0.1739
# Epoch 233/300
# 39/39 - 0s - loss: 0.8520 - first_order_loss: 0.6416 - second_order_loss: 0.2104
# Epoch 234/300
# 39/39 - 0s - loss: 0.8001 - first_order_loss: 0.6412 - second_order_loss: 0.1589
# Epoch 235/300
# 39/39 - 0s - loss: 0.8379 - first_order_loss: 0.6413 - second_order_loss: 0.1963
# Epoch 236/300
# 39/39 - 0s - loss: 0.8152 - first_order_loss: 0.6537 - second_order_loss: 0.1616
# Epoch 237/300
# 39/39 - 0s - loss: 0.8207 - first_order_loss: 0.6340 - second_order_loss: 0.1866
# Epoch 238/300
# 39/39 - 0s - loss: 0.8058 - first_order_loss: 0.6461 - second_order_loss: 0.1597
# Epoch 239/300
# 39/39 - 0s - loss: 0.8446 - first_order_loss: 0.6548 - second_order_loss: 0.1898
# Epoch 240/300
# 39/39 - 0s - loss: 0.8128 - first_order_loss: 0.6450 - second_order_loss: 0.1677
# Epoch 241/300
# 39/39 - 0s - loss: 0.8305 - first_order_loss: 0.6378 - second_order_loss: 0.1928
# Epoch 242/300
# 39/39 - 0s - loss: 0.8107 - first_order_loss: 0.6471 - second_order_loss: 0.1636
# Epoch 243/300
# 39/39 - 0s - loss: 0.8316 - first_order_loss: 0.6427 - second_order_loss: 0.1890
# Epoch 244/300
# 39/39 - 0s - loss: 0.8354 - first_order_loss: 0.6583 - second_order_loss: 0.1771
# Epoch 245/300
# 39/39 - 0s - loss: 0.8051 - first_order_loss: 0.6277 - second_order_loss: 0.1773
# Epoch 246/300
# 39/39 - 0s - loss: 0.8620 - first_order_loss: 0.6614 - second_order_loss: 0.2008
# Epoch 247/300
# 39/39 - 0s - loss: 0.8204 - first_order_loss: 0.6398 - second_order_loss: 0.1804
# Epoch 248/300
# 39/39 - 0s - loss: 0.8129 - first_order_loss: 0.6435 - second_order_loss: 0.1695
# Epoch 249/300
# 39/39 - 0s - loss: 0.8343 - first_order_loss: 0.6435 - second_order_loss: 0.1906
# Epoch 250/300
# 39/39 - 0s - loss: 0.8146 - first_order_loss: 0.6446 - second_order_loss: 0.1700
# Epoch 251/300
# 39/39 - 0s - loss: 0.8684 - first_order_loss: 0.6519 - second_order_loss: 0.2165
# Epoch 252/300
# 39/39 - 0s - loss: 0.8126 - first_order_loss: 0.6556 - second_order_loss: 0.1568
# Epoch 253/300
# 39/39 - 0s - loss: 0.8119 - first_order_loss: 0.6308 - second_order_loss: 0.1809
# Epoch 254/300
# 39/39 - 0s - loss: 0.8260 - first_order_loss: 0.6462 - second_order_loss: 0.1798
# Epoch 255/300
# 39/39 - 0s - loss: 0.8614 - first_order_loss: 0.6537 - second_order_loss: 0.2078
# Epoch 256/300
# 39/39 - 0s - loss: 0.8066 - first_order_loss: 0.6484 - second_order_loss: 0.1582
# Epoch 257/300
# 39/39 - 0s - loss: 0.8316 - first_order_loss: 0.6342 - second_order_loss: 0.1977
# Epoch 258/300
# 39/39 - 0s - loss: 0.8353 - first_order_loss: 0.6481 - second_order_loss: 0.1871
# Epoch 259/300
# 39/39 - 0s - loss: 0.8483 - first_order_loss: 0.6498 - second_order_loss: 0.1986
# Epoch 260/300
# 39/39 - 0s - loss: 0.8208 - first_order_loss: 0.6534 - second_order_loss: 0.1673
# Epoch 261/300
# 39/39 - 0s - loss: 0.8418 - first_order_loss: 0.6494 - second_order_loss: 0.1923
# Epoch 262/300
# 39/39 - 0s - loss: 0.8125 - first_order_loss: 0.6412 - second_order_loss: 0.1712
# Epoch 263/300
# 39/39 - 0s - loss: 0.8253 - first_order_loss: 0.6418 - second_order_loss: 0.1837
# Epoch 264/300
# 39/39 - 0s - loss: 0.8442 - first_order_loss: 0.6500 - second_order_loss: 0.1942
# Epoch 265/300
# 39/39 - 0s - loss: 0.7880 - first_order_loss: 0.6231 - second_order_loss: 0.1648
# Epoch 266/300
# 39/39 - 0s - loss: 0.8412 - first_order_loss: 0.6645 - second_order_loss: 0.1767
# Epoch 267/300
# 39/39 - 0s - loss: 0.8365 - first_order_loss: 0.6434 - second_order_loss: 0.1930
# Epoch 268/300
# 39/39 - 0s - loss: 0.8362 - first_order_loss: 0.6519 - second_order_loss: 0.1843
# Epoch 269/300
# 39/39 - 0s - loss: 0.8452 - first_order_loss: 0.6548 - second_order_loss: 0.1906
# Epoch 270/300
# 39/39 - 0s - loss: 0.8224 - first_order_loss: 0.6466 - second_order_loss: 0.1759
# Epoch 271/300
# 39/39 - 0s - loss: 0.8255 - first_order_loss: 0.6439 - second_order_loss: 0.1815
# Epoch 272/300
# 39/39 - 0s - loss: 0.8260 - first_order_loss: 0.6429 - second_order_loss: 0.1833
# Epoch 273/300
# 39/39 - 0s - loss: 0.8317 - first_order_loss: 0.6476 - second_order_loss: 0.1841
# Epoch 274/300
# 39/39 - 0s - loss: 0.8418 - first_order_loss: 0.6613 - second_order_loss: 0.1805
# Epoch 275/300
# 39/39 - 0s - loss: 0.8448 - first_order_loss: 0.6577 - second_order_loss: 0.1869
# Epoch 276/300
# 39/39 - 0s - loss: 0.7891 - first_order_loss: 0.6388 - second_order_loss: 0.1501
# Epoch 277/300
# 39/39 - 0s - loss: 0.8310 - first_order_loss: 0.6442 - second_order_loss: 0.1867
# Epoch 278/300
# 39/39 - 0s - loss: 0.8189 - first_order_loss: 0.6469 - second_order_loss: 0.1722
# Epoch 279/300
# 39/39 - 0s - loss: 0.8345 - first_order_loss: 0.6407 - second_order_loss: 0.1938
# Epoch 280/300
# 39/39 - 0s - loss: 0.8152 - first_order_loss: 0.6448 - second_order_loss: 0.1705
# Epoch 281/300
# 39/39 - 0s - loss: 0.8357 - first_order_loss: 0.6450 - second_order_loss: 0.1906
# Epoch 282/300
# 39/39 - 0s - loss: 0.8161 - first_order_loss: 0.6528 - second_order_loss: 0.1632
# Epoch 283/300
# 39/39 - 0s - loss: 0.8286 - first_order_loss: 0.6446 - second_order_loss: 0.1839
# Epoch 284/300
# 39/39 - 0s - loss: 0.8473 - first_order_loss: 0.6584 - second_order_loss: 0.1889
# Epoch 285/300
# 39/39 - 0s - loss: 0.8085 - first_order_loss: 0.6347 - second_order_loss: 0.1737
# Epoch 286/300
# 39/39 - 0s - loss: 0.7996 - first_order_loss: 0.6441 - second_order_loss: 0.1553
# Epoch 287/300
# 39/39 - 0s - loss: 0.8237 - first_order_loss: 0.6355 - second_order_loss: 0.1882
# Epoch 288/300
# 39/39 - 0s - loss: 0.8316 - first_order_loss: 0.6501 - second_order_loss: 0.1815
# Epoch 289/300
# 39/39 - 0s - loss: 0.7983 - first_order_loss: 0.6350 - second_order_loss: 0.1634
# Epoch 290/300
# 39/39 - 0s - loss: 0.8503 - first_order_loss: 0.6557 - second_order_loss: 0.1948
# Epoch 291/300
# 39/39 - 0s - loss: 0.8046 - first_order_loss: 0.6479 - second_order_loss: 0.1567
# Epoch 292/300
# 39/39 - 0s - loss: 0.8023 - first_order_loss: 0.6402 - second_order_loss: 0.1622
# Epoch 293/300
# 39/39 - 0s - loss: 0.8582 - first_order_loss: 0.6505 - second_order_loss: 0.2078
# Epoch 294/300
# 39/39 - 0s - loss: 0.8142 - first_order_loss: 0.6438 - second_order_loss: 0.1703
# Epoch 295/300
# 39/39 - 0s - loss: 0.8156 - first_order_loss: 0.6339 - second_order_loss: 0.1816
# Epoch 296/300
# 39/39 - 0s - loss: 0.8155 - first_order_loss: 0.6435 - second_order_loss: 0.1719
# Epoch 297/300
# 39/39 - 0s - loss: 0.8110 - first_order_loss: 0.6339 - second_order_loss: 0.1771
# Epoch 298/300
# 39/39 - 0s - loss: 0.8211 - first_order_loss: 0.6548 - second_order_loss: 0.1663
# Epoch 299/300
# 39/39 - 0s - loss: 0.8172 - first_order_loss: 0.6367 - second_order_loss: 0.1802
# Epoch 300/300
# 39/39 - 0s - loss: 0.7981 - first_order_loss: 0.6366 - second_order_loss: 0.1615

# %%
negative_edges = get_negative_edges(ori_df, ori_G)
train_df = ori_df

df_neg = pd.DataFrame(list(negative_edges), columns=['id_1', 'id_2'])
train_df = train_df.values
df_neg = df_neg.values

train_df = combine_embedding(train_df, LINE_embeddings)
df_neg = combine_embedding(df_neg, LINE_embeddings)

X_train_neg = df_neg

y_train_pos = np.ones(len(train_df))
y_train_neg = np.zeros(len(X_train_neg))

# %%
X_train = np.concatenate((train_df, X_train_neg))
y_train = np.concatenate((y_train_pos, y_train_neg))

# %%
clf = RandomForestClassifier(n_estimators=400)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=400)

# %%
all_edges = []
for i in range(34):
    for j in range(34):
        all_edges.append([i, j])
        
all_edges = pd.DataFrame(all_edges, columns=['id1', 'id2'])

all_df = all_edges.values
all_df = combine_embedding(all_df, LINE_embeddings)

all_df = np.array([list(all_df[i]) for i in range(len(all_df))])

predict_Y = clf.predict(all_df)

adj_rec = predict_Y.reshape(34, 34)

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

for i in range(34):
    for j in range(34):
        if i>=j :
            adj_rec[i, j] = 0

adj_rec = adj_rec + adj_rec.T

# %%
predict_edges = adj_rec.reshape(adj_rec.shape[0]*adj_rec.shape[0])

adj_true = nx.adjacency_matrix(ori_G).todense()
adj_true = np.array(adj_true)
true_edges = adj_true.reshape(34*34)

print("edges： ",predict_edges.sum())
print("ACC： ",accuracy_score(true_edges, predict_edges))
print("AP： ",precision_score(true_edges, predict_edges, average='macro'))
print("RECALL： ",recall_score(true_edges, predict_edges, average='macro'))
print("F1 SCORE： ",f1_score(true_edges, predict_edges, average='macro'))
# Out:
# edges：  204.0
# ACC：  0.8062283737024222
# AP：  0.6204481792717087
# RECALL：  0.649948717948718
# F1 SCORE：  0.6315118397085611

# %%
predict_graph = predict_edges.reshape(34, 34)
pd.DataFrame(predict_graph).to_csv('LINE_recon_karate.txt', header=None, index=False, sep=' ')
